# %%
import torch
import cv2
import matplotlib.pyplot as plt
import torchvision
import numpy as np

# %%
from ultralytics import YOLO
# model = YOLO("yolov8s.pt")

# %%
#!yolo task=detect mode=train model=yolov8s.pt data=dataset.yaml epochs=25 imgsz=320 plots=True

# %%
# /opt/homebrew/runs/detect/train9/weights

# %%
# !pip install ultralytics --no-deps

# %%
model = YOLO("/opt/homebrew/runs/detect/train9/weights/best.pt")

# %%
cap = cv2.VideoCapture(0)
for _ in range(50):
    ret, frame = cap.read()
pred = 15

while cap.isOpened():
    ret, frame = cap.read()
    
    results = model(frame)
    # print(results[0])
    # if results.pred[0].shape[0] == 1:
    #     if int(results.pred[0][0][5]) == 16:
    #         pred = 16 #open
    #     elif int(results.pred[0][0][5]) == 15:
    #         pred = 15 #close
    # elif results.pred[0].shape[0] > 1:
    #     flag = False
    #     for i in range(results.pred[0].shape[0]):
    #         if int(results.pred[0][i][5]) == 16:
    #             flag = True  #open
    #         elif int(results.pred[0][i][5]) == 15:
    #             flag = False
    #     if flag:
    #         pred = 16
    #     else:
    #         pred = 15
    # elif results.pred[0].shape[0] == 0:
    #results.pred[0].shape[0] == 1:
        if int(results.pred[0][0][5]) == 16:     pred = 15
    results[0].show()
    print(pred)
        
    
    cv2.imshow('prediction', np.squeeze(results[0].orig_img))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 192x320 1 open, 109.7ms
# Speed: 2.9ms preprocess, 109.7ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 320)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([16.])
# conf: tensor([0.9576])
# data: tensor([[217.9702, 175.9468, 615.6047, 605.5118,   0.9576,  16.0000]])
# id: None
# is_track: False
# orig_shape: (720, 1280)
# shape: torch.Size([1, 6])
# xywh: tensor([[416.7875, 390.7293, 397.6345, 429.5651]])
# xywhn: tensor([[0.3256, 0.5427, 0.3107, 0.5966]])
# xyxy: tensor([[217.9702, 175.9468, 615.6047, 605.5118]])
# xyxyn: tensor([[0.1703, 0.2444, 0.4809, 0.8410]])
# 16
#
# 0: 192x320 1 open, 75.5ms
# Speed: 0.9ms preprocess, 75.5ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 320)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([16.])
# conf: tensor([0.9657])
# data: tensor([[220.5150, 175.8121, 611.0145, 602.6678,   0.9657,  16.0000]])
# id: None
# is_track: False
# orig_shape: (720, 1280)
# ...
